# %%
import datetime
import tarfile
import boto3 # AWS SDK for python. Provides low-level access to AWS services
from sagemaker import get_execution_role
import sagemaker
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.session import s3_input, Session
from sagemaker.sklearn.estimator import SKLearn
 
bucket_name = 'cs205-final'
s3 = boto3.resource('s3')

# %%
healthy_uri = f"s3://{bucket_name}/healthy.tsv"
cancer_uri = f"s3://{bucket_name}/675_cancer.tsv"

# %%
custom_estimator = SKLearn(entry_point = 'GENIE3-sagemaker.py',
                            role=get_execution_role(),
                            instance_type='ml.m4.xlarge',
                            framework_version='0.20.0',
                            hyperparameters = {'start_idx': 10, 'stop_idx': 110, 'n_jobs': -1, 'fname': 'healthy_100_alljobs'})

# %%
custom_estimator.fit({'train':healthy_uri})
# Out:
# 2021-05-07 02:11:25 Starting - Starting the training job...
# 2021-05-07 02:11:48 Starting - Launching requested ML instancesProfilerReport-1620353484: InProgress
# ......
# 2021-05-07 02:12:48 Starting - Preparing the instances for training.........
# 2021-05-07 02:14:17 Downloading - Downloading input data...
# 2021-05-07 02:14:49 Training - Downloading the training image...
# 2021-05-07 02:15:13 Training - Training image download completed. Training in progress.2021-05-07 02:15:14,760 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-05-07 02:15:14,763 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-07 02:15:14,775 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-05-07 02:15:15,340 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-07 02:15:16,781 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-07 02:15:16,797 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-05-07 02:15:16,811 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "fname": "healthy_100_alljobs",
#         "n_jobs": -1,
#         "start_idx": 10,
#         "stop_idx": 110
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-05-07-02-11-24-628",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-035818970945/sagemaker-scikit-learn-2021-05-07-02-11-24-628/source/sourcedir.tar.gz",
#     "module_name": "GENIE3-sagemaker",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "GENIE3-sagemaker.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"fname":"healthy_100_alljobs","n_jobs":-1,"start_idx":10,"stop_idx":110}
# SM_USER_ENTRY_POINT=GENIE3-sagemaker.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=GENIE3-sagemaker
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-035818970945/sagemaker-scikit-learn-2021-05-07-02-11-24-628/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"fname":"healthy_100_alljobs","n_jobs":-1,"start_idx":10,"stop_idx":110},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-05-07-02-11-24-628","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-035818970945/sagemaker-scikit-learn-2021-05-07-02-11-24-628/source/sourcedir.tar.gz","module_name":"GENIE3-sagemaker","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"GENIE3-sagemaker.py"}
# SM_USER_ARGS=["--fname","healthy_100_alljobs","--n_jobs","-1","--start_idx","10","--stop_idx","110"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_FNAME=healthy_100_alljobs
# SM_HP_N_JOBS=-1
# SM_HP_START_IDX=10
# SM_HP_STOP_IDX=110
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python GENIE3-sagemaker.py --fname healthy_100_alljobs --n_jobs -1 --start_idx 10 --stop_idx 110
#
#
# /miniconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/cloudpickle/cloudpickle.py:47: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp
# /miniconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# /miniconda3/lib/python3.7/site-packages/sklearn/ensemble/gradient_boosting.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# 10
# 110
# Tree method: RF
# K: sqrt
# Number of trees: 1000
#
#
# running single threaded jobs
# Gene 10/110...
# Gene 11/110...
# Gene 12/110...
# Gene 13/110...
# Gene 14/110...
# Gene 15/110...
# Gene 16/110...
# Gene 17/110...
# Gene 18/110...
# Gene 19/110...
# Gene 20/110...
# Gene 21/110...
# Gene 22/110...
# Gene 23/110...
# Gene 24/110...
# Gene 25/110...
# Gene 26/110...
# Gene 27/110...
# Gene 28/110...
# Gene 29/110...
# Gene 30/110...
# Gene 31/110...
# Gene 32/110...
# Gene 33/110...
# Gene 34/110...
# Gene 35/110...
# Gene 36/110...
# Gene 37/110...
# Gene 38/110...
# Gene 39/110...
# Gene 40/110...
# Gene 41/110...
# Gene 42/110...
# Gene 43/110...
# Gene 44/110...
# Gene 45/110...
# Gene 46/110...
# Gene 47/110...
# Gene 48/110...
# Gene 49/110...
# Gene 50/110...
# Gene 51/110...
# Gene 52/110...
# Gene 53/110...
# Gene 54/110...
# Gene 55/110...
# Gene 56/110...
# Gene 57/110...
# Gene 58/110...
# Gene 59/110...
# Gene 60/110...
# Gene 61/110...
# Gene 62/110...
# Gene 63/110...
# Gene 64/110...
# Gene 65/110...
# Gene 66/110...
# Gene 67/110...
# Gene 68/110...
# Gene 69/110...
# Gene 70/110...
# Gene 71/110...
# Gene 72/110...
# Gene 73/110...
# Gene 74/110...
# Gene 75/110...
# Gene 76/110...
# Gene 77/110...
# Gene 78/110...
# Gene 79/110...
# Gene 80/110...
# Gene 81/110...
# Gene 82/110...
# Gene 83/110...
# Gene 84/110...
# Gene 85/110...
# Gene 86/110...
# Gene 87/110...
# Gene 88/110...
# Gene 89/110...
# Gene 90/110...
# Gene 91/110...
# Gene 92/110...
# Gene 93/110...
# Gene 94/110...
# Gene 95/110...
# Gene 96/110...
# Gene 97/110...
# Gene 98/110...
# Gene 99/110...
# Gene 100/110...
# Gene 101/110...
# Gene 102/110...
# Gene 103/110...
# Gene 104/110...
# Gene 105/110...
# Gene 106/110...
# Gene 107/110...
# Gene 108/110...
# Gene 109/110...
# Elapsed time: 488.20 seconds
#
# 2021-05-07 02:23:57 Uploading - Uploading generated training modelNone
# 2021-05-07 02:23:56,433 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-05-07 02:24:31 Completed - Training job completed
# ProfilerReport-1620353484: NoIssuesFound
# Training seconds: 593
# Billable seconds: 593

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a3a1fdb0-4946-49ac-bb9f-c39b38835b36' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
